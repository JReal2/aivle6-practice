# %% [markdown]
# # **성능관리**

# %% [markdown]
# ## **1.환경준비**

# %% [markdown]
# ### **(1) 라이브러리 로딩**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.preprocessing import MinMaxScaler

from keras.models import Sequential
from keras.layers import Dense, Flatten, Input
from keras.backend import clear_session
from keras.optimizers import Adam
from keras.datasets import mnist

# %% [markdown]
# * 함수 만들기

# %%
# 학습곡선 함수
def dl_history_plot(history):
    plt.figure(figsize=(10,6))
    plt.plot(history['loss'], label='train_err', marker = '.')
    plt.plot(history['val_loss'], label='val_err', marker = '.')

    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ### **(2) 데이터로딩**

# %% [markdown]
# * 데이터 로딩
#     * 과적합을 위한 예제 데이터입니다.
#     * target
#     * feature : 0 ~ 299

# %%
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/overfit_sample.csv"
data = pd.read_csv(path)
data.head()
# Out:
#    target      0      1      2      3      4      5      6      7      8  ...  \
# 0       1 -1.067 -1.114 -0.616  0.376  1.090  0.467 -0.422  0.460 -0.443  ...
# 1       0 -0.831  0.271  1.716  1.096  1.731 -0.197  1.904 -0.265  0.557  ...
# 2       0  0.099  1.390 -0.732 -1.065  0.005 -0.081 -1.450  0.317 -0.624  ...
# 3       1 -0.989 -0.916 -1.343  0.145  0.543  0.636  1.127  0.189 -0.118  ...
# 4       0  0.811 -1.509  0.522 -0.360 -0.220 -0.959  0.334 -0.566 -0.656  ...
#
#      290    291    292    293    294    295    296    297    298    299
# 0  0.220 -0.339  0.254 -0.179  0.352  0.125  0.347  0.436  0.958 -0.824
# 1 -0.765 -0.735 -1.158  2.554  0.856 -1.506  0.462 -0.029 -1.932 -0.343
# 2 -1.311  0.799 -1.001  1.544  0.575 -0.309 -0.339 -0.148 -0.646  0.725
# 3 -1.370  1.093  0.596 -0.589 -0.649 -0.163 -0.958 -1.081  0.805  3.401
# 4 -0.178  0.718 -1.017  1.249 -0.596 -0.445  1.751  1.442 -0.393 -0.643
#
# [5 rows x 301 columns]

# %%
data.shape
# Out:
# (250, 301)

# %% [markdown]
# ## **2. Early Stopping**

# %% [markdown]
# ### **(1) 데이터 준비**

# %%
# 데이터분할 : x, y
target = 'target'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# 데이터분할 : train, validation
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.2, random_state = 20)

# %%
# 스케일링
scaler = MinMaxScaler()
x_train = scaler.fit_transform(x_train)
x_val = scaler.transform(x_val)

# %% [markdown]
# ### **(2) 모델링**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(3) 미리 멈춤!(Early Stopping)**

# %% [markdown]
# #### 1) 함수 불러오기

# %%
from keras.callbacks import EarlyStopping

# %% [markdown]
# #### 2) 모델링 with early stopping

# %%
# 모델 선언
clear_session()

model2 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )
model2.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# EarlyStopping 설정 ------------
min_de = 0.001
pat = 5

es = EarlyStopping(monitor = 'val_loss', min_delta = min_de, patience = pat)
# --------------------------------

# 학습
hist = model2.fit(x_train, y_train, epochs = 100, validation_split=0.2,
                  callbacks = [es]).history
dl_history_plot(hist)
# Out:
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - loss: 0.6615 - val_loss: 0.5860
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5727 - val_loss: 0.5880
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5508 - val_loss: 0.5850
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5329 - val_loss: 0.5828
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5830 - val_loss: 0.5845
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6072 - val_loss: 0.5845
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5099 - val_loss: 0.5845
# Epoch 8/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5340 - val_loss: 0.5833
# Epoch 9/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5362 - val_loss: 0.5813
# Epoch 10/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4910 - val_loss: 0.5778
# Epoch 11/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5269 - val_loss: 0.5758
# Epoch 12/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4936 - val_loss: 0.6046
# Epoch 13/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4714 - val_loss: 0.5845
# Epoch 14/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5183 - val_loss: 0.5969
# Epoch 15/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5083 - val_loss: 0.5842
# Epoch 16/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4034 - val_loss: 0.5847

# %% [markdown]
# ## 3.Dropout

# %%
from keras.layers import Dropout

# %% [markdown]
# ### **(1) 적용 전**

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model1.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) 적용 후**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model3 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu'),
                      Dropout(0.4),
                      Dense(64, activation= 'relu'),
                      Dropout(0.4),
                      Dense(32, activation= 'relu'),
                      Dropout(0.4),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model3.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model3.fit(x_train, y_train, epochs = 50, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## 4.모델 저장하기

# %% [markdown]
# ### (1) 모델 저장하기
#
# * model.save(‘파일이름.keras’)
#     * 딥러닝 모델의 메소드로 .save가 제공됩니다.
#     * 파일이름.keras 파일이 저장됩니다.

# %%
model1.save('/content/drive/MyDrive/Deep_Learning/leejr.keras')

# %% [markdown]
# * 저장된 파일은 왼쪽 '파일'탭에서 확인 가능
# * 파일을 다운로드 받을 수 있다.

# %% [markdown]
# ### (2) 모델 로딩하기
#
# * load_model 함수는 별도로 불러와야 합니다.
# * 경로를 맞춰주고 h5 파일을 읽어오면 그대로 사용 가능합니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.models import load_model
model2 = load_model('/content/drive/MyDrive/Deep_Learning/leejr.keras')

# %% [markdown]
# * 불러온 모델 사용하기

# %%
pred2 = model2.predict(x_val)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 458ms/step

# %%
pred2
# Out:
# array([[3.85641877e-04],
#        [6.57719420e-03],
#        [2.43447393e-01],
#        [2.69996515e-03],
#        [1.24039405e-04],
#        [6.97569728e-01],
#        [3.61109618e-03],
#        [3.42791434e-04],
#        [3.41320713e-03],
#        [5.43645263e-01],
#        [8.64117965e-03],
#        [2.42754890e-04],
#        [4.46927916e-05],
#        [2.05290347e-01],
#        [6.55555399e-04],
#        [1.87832098e-02],
#        [2.79273198e-04],
#        [5.01053128e-03],
#        [2.77681829e-04],
#        [8.07523975e-06],
#        [1.93725780e-01],
#        [3.51857513e-01],
#        [1.07631111e-03],
#        [7.56242722e-02],
#        [5.35157584e-02],
#        [8.45220983e-01],
#        [2.81128829e-04],
#        [2.34100651e-02],
#        [8.81241649e-05],
#        [2.76357023e-04],
#        [5.52749448e-02],
#        [3.84061335e-04],
#        [7.83366384e-04],
#        [8.35329965e-02],
#        [6.22911437e-04],
#        [3.87222826e-04],
#        [2.89114279e-04],
#        [4.61536110e-04],
#        [8.96915980e-03],
#        [1.71175748e-01],
#        [8.41289386e-03],
#        [8.07078302e-01],
#        [9.96327460e-01],
#        [6.09427370e-05],
#        [1.19945854e-01],
#        [2.95321979e-02],
#        [4.64084951e-05],
#        [1.01378595e-03],
#        [1.22989155e-02],
#        [7.19798982e-06]], dtype=float32)

# %%
pred2_1 = np.where(pred2> .5, 1, 0)

# %%
print(accuracy_score(y_val,pred2_1))
print('-'*60)
print(confusion_matrix(y_val, pred2_1))
print('-'*60)
print(classification_report(y_val, pred2_1))
# Out:
# 0.72
# ------------------------------------------------------------
# [[33  2]
#  [12  3]]
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.73      0.94      0.82        35
#            1       0.60      0.20      0.30        15
#
#     accuracy                           0.72        50
#    macro avg       0.67      0.57      0.56        50
# weighted avg       0.69      0.72      0.67        50

# %% [markdown]
# ### (3) 중간 체크포인트에 모델 저장하기

# %% [markdown]
# * 폴더 정리 : 위에서 저장한 파일들 제거하기

# %%
import os

def delete_h5_files(directory):
    for filename in os.listdir(directory):
        if filename.endswith(".keras"):
            file_path = os.path.join(directory, filename)
            try:
                os.remove(file_path)
                print(f"Deleted: {file_path}")
            except Exception as e:
                print(f"Error deleting {file_path}: {e}")

# 삭제할 디렉토리 지정
directory_to_delete_from = "/content/"

# 확장자가 .h5인 파일 삭제
delete_h5_files(directory_to_delete_from)
# Out:
# Deleted: /content/leejr.keras

# %% [markdown]
# #### 1) 체크포인트 함수 불러오기

# %%
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### 2) 모델링 체크포인트 저장

# %% [markdown]
# * 모델 선언

# %%
# input_shape : feature 수 도출
nfeatures = x_train.shape[1]

# 메모리 정리
clear_session()

# Sequential 타입
model1 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(64, activation= 'relu'),
                      Dense(32, activation= 'relu'),
                      Dense(16, activation= 'relu'),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model1.compile(optimizer= Adam(learning_rate = 0.0001), loss='binary_crossentropy')

# %% [markdown]
# * 체크포인트 저장
#     * 아래 코드에서 ModelCheckpoint 콜백은 검증 데이터의 정확도(val_accuracy)를 기준으로 모델 저장
#     * 모델의 성능이 이전에 저장된 모델보다 향상될 때만 저장되도록 save_best_only=True로 설정
#     * 또한, verbose=1로 설정하면 모델이 저장될 때마다 콘솔에 메시지가 표시됨.

# %%
cp_path = '/content/{epoch:03d}.keras'  # Keras 2.11 이상 버전에서 모델 확장자 .keras
mcp = ModelCheckpoint(cp_path, monitor='val_loss', verbose = 1, save_best_only=True)

# 학습
hist = model1.fit(x_train, y_train, epochs = 50, validation_split=.2, callbacks=[mcp]).history
# Out:
# Epoch 1/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 10s 3s/step - loss: 0.7880
# Epoch 1: val_loss improved from inf to 0.73059, saving model to /content/001.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - loss: 0.7704 - val_loss: 0.7306
# Epoch 2/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6992
# Epoch 2: val_loss improved from 0.73059 to 0.69226, saving model to /content/002.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7054 - val_loss: 0.6923
# Epoch 3/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.6733
# Epoch 3: val_loss improved from 0.69226 to 0.66175, saving model to /content/003.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6739 - val_loss: 0.6618
# Epoch 4/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6456
# Epoch 4: val_loss improved from 0.66175 to 0.63501, saving model to /content/004.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6425 - val_loss: 0.6350
# Epoch 5/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6364
# Epoch 5: val_loss improved from 0.63501 to 0.61247, saving model to /content/005.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6227 - val_loss: 0.6125
# Epoch 6/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6234
# Epoch 6: val_loss improved from 0.61247 to 0.59666, saving model to /content/006.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6068 - val_loss: 0.5967
# Epoch 7/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.6027
# Epoch 7: val_loss improved from 0.59666 to 0.58663, saving model to /content/007.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5861 - val_loss: 0.5866
# Epoch 8/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5760
# Epoch 8: val_loss improved from 0.58663 to 0.58281, saving model to /content/008.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5876 - val_loss: 0.5828
# Epoch 9/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.5535
# Epoch 9: val_loss improved from 0.58281 to 0.58160, saving model to /content/009.keras
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5353 - val_loss: 0.5816
# Epoch 10/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.5463
# Epoch 10: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5518 - val_loss: 0.5820
# Epoch 11/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4476
# Epoch 11: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5452 - val_loss: 0.5820
# Epoch 12/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7020
# Epoch 12: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6017 - val_loss: 0.5816
# Epoch 13/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5651
# Epoch 13: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5338 - val_loss: 0.5819
# Epoch 14/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6492
# Epoch 14: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5860 - val_loss: 0.5816
# Epoch 15/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4505
# Epoch 15: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5171 - val_loss: 0.5818
# Epoch 16/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.4118
# Epoch 16: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5161 - val_loss: 0.5821
# Epoch 17/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.5682
# Epoch 17: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5492 - val_loss: 0.5824
# Epoch 18/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5447
# Epoch 18: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5509 - val_loss: 0.5828
# Epoch 19/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4486
# Epoch 19: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5105 - val_loss: 0.5832
# Epoch 20/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5884
# Epoch 20: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5540 - val_loss: 0.5840
# Epoch 21/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5470
# Epoch 21: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5319 - val_loss: 0.5848
# Epoch 22/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4982
# Epoch 22: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5291 - val_loss: 0.5852
# Epoch 23/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5952
# Epoch 23: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5654 - val_loss: 0.5854
# Epoch 24/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4793
# Epoch 24: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5341 - val_loss: 0.5854
# Epoch 25/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6643
# Epoch 25: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5677 - val_loss: 0.5853
# Epoch 26/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4683
# Epoch 26: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5323 - val_loss: 0.5852
# Epoch 27/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5098
# Epoch 27: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5602 - val_loss: 0.5856
# Epoch 28/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5363
# Epoch 28: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5301 - val_loss: 0.5858
# Epoch 29/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5157
# Epoch 29: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5385 - val_loss: 0.5865
# Epoch 30/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4362
# Epoch 30: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5192 - val_loss: 0.5872
# Epoch 31/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5729
# Epoch 31: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5357 - val_loss: 0.5874
# Epoch 32/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.5359
# Epoch 32: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5504 - val_loss: 0.5873
# Epoch 33/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.5266
# Epoch 33: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5455 - val_loss: 0.5874
# Epoch 34/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6602
# Epoch 34: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5747 - val_loss: 0.5882
# Epoch 35/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5882
# Epoch 35: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5557 - val_loss: 0.5891
# Epoch 36/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6372
# Epoch 36: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5510 - val_loss: 0.5893
# Epoch 37/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.5947
# Epoch 37: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5535 - val_loss: 0.5894
# Epoch 38/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5297
# Epoch 38: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5534 - val_loss: 0.5894
# Epoch 39/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.5179
# Epoch 39: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5087 - val_loss: 0.5901
# Epoch 40/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5463
# Epoch 40: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5320 - val_loss: 0.5898
# Epoch 41/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.6670
# Epoch 41: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5622 - val_loss: 0.5899
# Epoch 42/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.5052
# Epoch 42: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5209 - val_loss: 0.5901
# Epoch 43/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4284
# Epoch 43: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5063 - val_loss: 0.5904
# Epoch 44/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.5475
# Epoch 44: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5238 - val_loss: 0.5906
# Epoch 45/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.5060
# Epoch 45: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5078 - val_loss: 0.5912
# Epoch 46/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.5951
# Epoch 46: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5421 - val_loss: 0.5916
# Epoch 47/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4612
# Epoch 47: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5069 - val_loss: 0.5926
# Epoch 48/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.4439
# Epoch 48: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5031 - val_loss: 0.5931
# Epoch 49/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4910
# Epoch 49: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5082 - val_loss: 0.5934
# Epoch 50/50
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4294
# Epoch 50: val_loss did not improve from 0.58160
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4803 - val_loss: 0.5940

# %%
# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ## **5.[참조]가중치 규제(Regularization)**

# %%
# 규제를 위해 필요한 함수 불러오기
from keras.regularizers import l1, l2

# %% [markdown]
# ### **(1) L1 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model4 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                              ),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l1(0.01)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model4.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model4.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)

# %% [markdown]
# ### **(2) L2 규제**

# %%
# 메모리 정리
clear_session()

# Sequential 타입
model5 = Sequential( [Input(shape = (nfeatures,)),
                      Dense(128, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(64, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(32, activation= 'relu',
                            kernel_regularizer = l2(0.05)),
                      Dense(1, activation= 'sigmoid')] )

# 컴파일
model5.compile(optimizer= Adam(learning_rate = 0.001), loss='binary_crossentropy')

# %%
# 학습
hist = model5.fit(x_train, y_train, epochs = 100, validation_split=0.2, verbose = 0).history

# 학습결과 그래프
dl_history_plot(hist)
