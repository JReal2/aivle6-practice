# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

sentence = ["오늘은 KT에서 강의하는 날입니다.", "오늘은 KT에서 강의하는 날이 아닙니다."]

vector = TfidfVectorizer(max_features=100)
vector_result = vector.fit_transform(sentence)

print(cosine_similarity(vector_result[0], vector_result[0]))
print(cosine_similarity(vector_result[0], vector_result[1]))

# %%
import numpy as np

group_A = np.zeros((15,2))
group_B = np.zeros((15,2))
group_C = np.zeros((15,2))

# 각 그룹마다 랜덤값 부여
# Group A는 100~200 실수값
# Group B는 0~50
# Group C는 x축은 100~200, y축은 0~50

#각 그룹의 점들과 우리가 갖고 있는 현재 point와의 거리를 구하는 함수
def distance(p, a):
  return a

k = 5


# 그룹별로 가까운 점 개수 세기
stat = [0, 0, 0]

# 최대로 큰 값의 위치를 구해 해당 그룹 출력
if index == 0:
    print("Group A")
elif index == 1:
    print("Group B")
else:
    print("Group C")
# Out:
# Group B
# [0, 5, 0]
